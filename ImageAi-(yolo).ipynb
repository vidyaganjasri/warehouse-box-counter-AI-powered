# %%
# !pip install roboflow
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 87.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 27.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 38.6 MB/s eta 0:00:00
# ...

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="91qyWgt9RQhFY4gtZJvn")  # 🔑 replace with your real API key
project = rf.workspace("warehouseprojectssd").project("logistics-pdx9y-k2ik7")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Logistics-2 in yolov8:: 100%|██████████| 1084/1084 [00:00<00:00, 8565.87it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")  # use a light, fast model

model.train(
    data=f"{dataset.location}/data.yaml",  # this auto points to downloaded dataset
    epochs=50,     # you can lower for speed
    imgsz=640,
    batch=16,
    name="simple_retrain"
)
# Out:
# Ultralytics 8.3.158 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
results = model.predict(source=f"{dataset.location}/valid/images", save=True)
# Out:
# image 1/45 /content/Logistics-2/valid/images/1000_F_269283035_vxbhJ7FRdNmtE120d5eQRDkcV6LgAXMv_jpg.rf.c391070cb5ef300192316ff91900405e.jpg: 640x640 3 Boxs, 2 Pallets, 8.4ms
# image 2/45 /content/Logistics-2/valid/images/126727388-portrait-of-delivery-staff-in-blue-uniform-work-in-warehouse-hold-a-parcel-box-keep-goods-and-parcel_jpg.rf.b68324b3fb8bea7732cc7ba191363d62.jpg: 640x640 20 Boxs, 7.4ms
# image 3/45 /content/Logistics-2/valid/images/1645431930blog-banner_jpeg.rf.39456f6f9f92645e088239ea38a22ccb.jpg: 640x640 6 Boxs, 7.4ms
# image 4/45 /content/Logistics-2/valid/images/Optimise_your_warehouse_space-1_jpg.rf.3e1fe3b9333c15eb8e8d04b0b19df345.jpg: 640x640 12 Boxs, 1 Pallet, 7.4ms
# image 5/45 /content/Logistics-2/valid/images/Option-for-Parcel-Sortation-and-Distribution-Feature-Image_jpg.rf.056cce25c7e0da5e7cb0b4948e67141e.jpg: 640x640 6 Boxs, 7.4ms
# ...

# %%
metrics = model.val()
# Out:
# Ultralytics 8.3.158 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1367.9±453.9 MB/s, size: 37.6 KB)
# val: Scanning /content/Logistics-2/valid/labels.cache... 45 images, 0 backgrounds, 0 corrupt: 100%|██████████| 45/45 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 47, len(boxes) = 431. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:02<00:00,  1.47it/s]
#                    all         45        431      0.614      0.426      0.411      0.286
#                    Box         43        395      0.589      0.673      0.637      0.427
#                 Crates          2          3      0.894      0.333      0.357      0.281
# ...

# %%
import pandas as pd

df = pd.read_csv("runs/detect/simple_retrain/results.csv")
print("🧾 Available columns:\n")
print(df.columns.tolist())
# Out:
# 🧾 Available columns:
#
# ['epoch', 'time', 'train/box_loss', 'train/cls_loss', 'train/dfl_loss', 'metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)', 'val/box_loss', 'val/cls_loss', 'val/dfl_loss', 'lr/pg0', 'lr/pg1', 'lr/pg2']

# %%
df.columns = df.columns.str.strip()  # remove leading/trailing spaces

# %%
from tabulate import tabulate

final_metrics = df.iloc[-1]

table = [
    ["Metric", "Score"],
    ["mAP50", f"{final_metrics['metrics/mAP50(B)']:.4f}"],
    ["mAP50-95", f"{final_metrics['metrics/mAP50-95(B)']:.4f}"],
    ["Precision", f"{final_metrics['metrics/precision(B)']:.4f}"],
    ["Recall", f"{final_metrics['metrics/recall(B)']:.4f}"]
]

print(tabulate(table, headers="firstrow", tablefmt="fancy_grid"))
# Out:
# ╒═══════════╤═════════╕
# │ Metric    │   Score │
# ╞═══════════╪═════════╡
# │ mAP50     │  0.4468 │
# ├───────────┼─────────┤
# │ mAP50-95  │  0.2936 │
# ├───────────┼─────────┤
# │ Precision │  0.3423 │
# ├───────────┼─────────┤
# │ Recall    │  0.5234 │
# ╘═══════════╧═════════╛
